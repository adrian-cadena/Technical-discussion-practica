# %% [markdown]
# <a href="https://colab.research.google.com/github/adrian-cadena/Technical-discussion-practica/blob/main/Technical_Discussion_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Primer entrada con Python para una discusion tecnica
# * Como paso inicial tenemos una entrada en python que imprime "hola mundo"
# * Como segundo punto queda conectarlo con nuestro repositorio de GitHub

# %%
def saludo():
  return "Hola mundo"
saludo()
# Out:
# 'Hola mundo'

# %% [markdown]
# ## División de actividades durante un proyecto
# podemos ingresar texto a lo largo de nuestro proyecto para ir separando las funciones y explicar como funcinan

# %%
def sumaNumeros():
  a=5
  b=10
  return a+b
sumaNumeros()
# Out:
# 15
